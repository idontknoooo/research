# %%
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import requests
import re
import codecs
import time
# import pyodbc

# %%
# Create item_id: 00000-000 for each item
# Add save everything in 1 .txt file
# Migrate to Windows

# %%
with open("cv-A.txt") as f:
    contents = f.readlines()

contents = [x.strip() for x in contents]
for content in contents:
    tmp = content.split(' --- ')
    last_name = tmp[0].split(' ')[0]
    first_name = tmp[0].split(' ')[1]
    start_year = ''
    end_year = ''
    if tmp[1]:
        year_tmp = tmp[1].split('-')
        start_year = year_tmp[0]
        if len(year_tmp) > 1 and year_tmp[1].isdigit():
            end_year = year_tmp[1]
    title = tmp[2]
    info = []
    info_id = []
    location = []
    location_id = []
    for pair in tmp[3:]:
        pair_split = pair.split(':')
        if pair_split[0][0] == '9':
            location_id.append(pair_split[0])
            location.append(pair_split[1])
        else:
            info_id.append(pair_split[0])
            info.append(pair_split[1])
    # tmp_final += id
    tmp_final = ''
    tmp_final = "'" + last_name + "','" + first_name + "','" + start_year + "','" + end_year + "','" + title + "','"
    for i, i_id in zip(info, info_id):
        tmp_final += i + "','" + i_id + "','"
    for loc, loc_id in zip(location, location_id):
        tmp_final += loc + "','" + loc_id + "','"
    if tmp_final[-2:] == ",'":
        tmp_final = tmp_final[:-2]
    tmp_final = '''"""''' + tmp_final + '''"""'''
    print(tmp_final)
# Out:
# """'Abdul','Abdulrixit','2008','2013','Member','CPPCC','1810.101','CPPCC-National Committee','1810.101001','CPC','1010.101','CPC-Leading Party Group','1010.101031'"""
# """'Abdul','Abdulrixit','2008','2013','Vice-Chairman','CPPCC','1810.101','CPPCC-National Committee','1810.101001'"""
# """'Abdul','Abdulrixit','2007','2012','Member','CPC','1010.101','CPC-Central Committee','1010.101001'"""
# """'Abdul','Abdulrixit','2003','2008','Deputy Secretary','CPC','1010.101','CPC-Autonomous Regional Committee','1010.101007','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Abdul','Abdulrixit','2003','2008','Member','CPPCC','1810.101','CPPCC-National Committee','1810.101001','CPC','1010.101','CPC-Leading Party Group','1010.101031'"""
# """'Abdul','Abdulrixit','2003','2003','Secretary','Autonomous Regional People's Congress','1610.901','CPC','1010.101','CPC-Leading Party Group','1010.101031','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Abdul','Abdulrixit','2003','','Chairman','Autonomous Regional People's Congress','1610.901','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Abdul','Abdulrixit','2003','2008','Vice-Chairman','CPPCC','1810.101','CPPCC-National Committee','1810.101001'"""
# """'Abdul','Abdulrixit','2002','2007','Member','CPC','1010.101','CPC-Central Committee','1010.101001'"""
# """'Abdul','Abdulrixit','1997','2002','Member','CPC','1010.101','CPC-Central Committee','1010.101001'"""
# """'Abdul','Abdulrixit','1994','2003','Chairman','Autonomous Regional People's Congress','1610.901','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Abdul','Abdulrixit','1994','2003','Deputy Secretary','CPC','1010.101','CPC-Autonomous Regional Committee','1010.101007','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Abdul','Abdulrixit','1994','2003','Chairman','Autonomous Region People's Government','2050.106','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Abdul','Abdulrixit','1993','1994','Deputy Secretary','CPC','1010.101','CPC-Autonomous Regional Committee','1010.101007','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Abdul','Abdulrixit','1993','1994','Acting Chairman','Autonomous Region People's Government','2050.106','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Abdul','Abdulrixit','1991','1993','Vice-Chairman','Autonomous Region People's Government','2050.106','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Abdul','Abdulrixit','1983','1991','Member','Planning Committee','2210.177','CPC','1010.101','CPC-Leading Party Group','1010.101031','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Abdul','Abdulrixit','1983','1991','Secretary','Planning Committee','2210.177','CPC','1010.101','CPC-Leading Party Group','1010.101031','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Abdul','Abdulrixit','1983','1991','Deputy Director','Planning Committee','2210.177','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Abdul','Abdulrixit','1980','1983','Deputy Director','Architectural Prospecting and Design Institute','2410.233','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Abdul','Abdulrixit','1965','1980','Technician and Engineer','Architectural Prospecting and Design Institute','2410.233','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Abdul','Abdulrixit','1960','1965','Student','Xinjiang Engineering Institute','6310.121','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Abdul','Abdulrixit','1960','','Joined','CPC','1010.101'"""
# """'Abdurehim','Amet','2008','2013','Vice-Chairman','Ethnic Affairs Committee of the NPC','1610.201'"""
# """'Abdurehim','Amet','2008','2013','Member','Standing Committee of the NPC','1610.101'"""
# """'Abdurehim','Amet','2004','2008','Chairman','Autonomous Regional People's Congress','1610.901','Autonomous Regional People's Congress-Standing Committee','1610.901001','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Abdurehim','Amet','2001','2004','Vice-Chairman','Autonomous Regional People's Congress','1610.901','Autonomous Regional People's Congress-Standing Committee','1610.901001','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Abdurehim','Amet','1993','2001','Member','CPC','1010.101','CPC-Autonomous Regional Committee','1010.101007','Autonomous Regional Committee-Standing Committee','1010.101007011','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Abdurehim','Amet','1983','1993','Deputy Secretary','CPC','1010.101','CPC-Autonomous Regional Committee','1010.101007','Autonomous Regional Committee-Commission for Discipline Inspection','1010.101007012','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Abdurehim','Amet','1981','1983','Deputy Secretary','CPC','1010.101','CPC-Autonomous Regional Committee','1010.101007','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Abdurehim','Amet','1979','1981','Section Chief','CPC','1010.101','CPC-Autonomous Regional Committee','1010.101007','Autonomous Regional Committee-Organization Department','1010.101007068','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Abdurehim','Amet','1977','1979','Secretary','CPC','1010.101','CPC-Autonomous County Committee','1010.101021','Xinjiang Uygur Autonomous Region','9560.035','Xinjiang Uygur Autonomous Region, Nilka County','9560.035031'"""
# """'Abdurehim','Amet','1975','1977','Director','Cultural Revolution','1020.101','Cultural Revolution-Revolutionary Committee','1020.101033','Xinjiang Uygur Autonomous Region','9560.035','Xinjiang Uygur Autonomous Region, Yining County','9560.035029'"""
# """'Abdurehim','Amet','1975','1977','Deputy Secretary','CPC','1010.101','CPC-Autonomous County Committee','1010.101021','Xinjiang Uygur Autonomous Region','9560.035','Xinjiang Uygur Autonomous Region, Yining County','9560.035029'"""
# """'Abdurehim','Amet','1973','1975','Secretary','Alstan Commune','6950.713','Xinjiang Uygur Autonomous Region','9560.035','Xinjiang Uygur Autonomous Region, Yining County','9560.035029'"""
# """'Abdurehim','Amet','1971','1973','Deputy Director','Tianshan Commune','6950.712','Cultural Revolution','1020.101','Cultural Revolution-Revolutionary Committee','1020.101033','Xinjiang Uygur Autonomous Region','9560.035','Xinjiang Uygur Autonomous Region, Yining County','9560.035029'"""
# """'Abdurehim','Amet','1966','1971','Deputy Secretary','Turpan Yuzi Commune','6950.711','CPC','1010.101','CPC-Party Committee','1010.101025','Xinjiang Uygur Autonomous Region','9560.035','Xinjiang Uygur Autonomous Region, Yining County','9560.035029'"""
# """'Abdurehim','Amet','1965','','Joined','CPC','1010.101'"""
# """'Abdurehim','Amet','1964','1965','Worker','Turpan Yuzi Commune','6950.711','Xinjiang Uygur Autonomous Region','9560.035','Xinjiang Uygur Autonomous Region, Yining County','9560.035029'"""
# """'Abdurehim','Amet','1959','1964','Student','Xinjiang Industry Institute','6310.125','Xinjiang Industry Institute-Mechanism Department','6310.125009','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Abudukader','Naisierding','1998','2008','Vice-Chairman','Autonomous Region People's Government','2050.106','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Abudukader','Naisierding','1993','1998','Special Commissioner','Prefectural Administrative Office','2410.111','Xinjiang Uygur Autonomous Region','9560.035','Xinjiang Uygur Autonomous Region, Kashi Prefecture','9560.035006'"""
# """'Abudukader','Naisierding','1985','1998','Member','CPC','1010.101','CPC-Autonomous Prefectural Committee','1010.101013','Xinjiang Uygur Autonomous Region','9560.035','Xinjiang Uygur Autonomous Region, Kashi Prefecture','9560.035006'"""
# """'Abudukader','Naisierding','1985','1998','Deputy Secretary','CPC','1010.101','CPC-Autonomous Prefectural Committee','1010.101013','Xinjiang Uygur Autonomous Region','9560.035','Xinjiang Uygur Autonomous Region, Kashi Prefecture','9560.035006'"""
# """'Abudukader','Naisierding','1973','','Joined','CPC','1010.101'"""
# """'Abudukader','Naisierding','1967','1985','Assistant Commissioner','Education Bureau','2190.124','Xinjiang Uygur Autonomous Region','9560.035','Xinjiang Uygur Autonomous Region, Jianshi','9560.035035'"""
# """'Abudukader','Naisierding','1967','1985','Bureau Chief','Education Bureau','2190.124','Xinjiang Uygur Autonomous Region','9560.035','Xinjiang Uygur Autonomous Region, Jianshi','9560.035035'"""
# """'Abudukader','Naisierding','1967','1985','Cadre','Xinjiang Uygur Autonomous Region','9560.035','Xinjiang Uygur Autonomous Region, Kashi Prefecture','9560.035006'"""
# """'Abudureyimu','Ajiyiming','2003','2008','Honorary Chairman','Xinjiang Federation of Returned Overseas Chinese','6750.239','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Abudureyimu','Ajiyiming','2003','2008','Vice-Chairman','CPC','1010.101','CPC-Autonomous Regional Committee','1010.101007','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Abudureyimu','Ajiyiming','2003','2008','Vice-Chairman','Autonomous Region People's Government','2050.106','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Abudureyimu','Ajiyiming','1998','2003','Vice-Chairman','CPC','1010.101','CPC-Autonomous Regional Committee','1010.101007','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Abudureyimu','Ajiyiming','1998','2003','Member','CPPCC','1810.101','CPPCC-National Committee','1810.101001','National Committee-Standing Committee','1810.101001002'"""
# """'Abudureyimu','Ajiyiming','1997','2007','Chairman','Xinjinang Federation of Industry and Commerce','6750.238','Xinjinang Federation of Industry and Commerce-Executive Committee','6750.238101','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Abudureyimu','Ajiyiming','1997','2007','Member','All-China Federation of Industry and Commerce','6750.126','All-China Federation of Industry and Commerce-Executive Committee','6750.126001'"""
# """'Abudureyimu','Ajiyiming','1993','1998','Deputy','NPC','1610.001'"""
# """'Abudureyimu','Ajiyiming','1993','1998','Member','CPC','1010.101','CPC-Autonomous Regional Committee','1010.101007','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Abudureyimu','Ajiyiming','1988','1993','Member','CPC','1010.101','CPC-Autonomous Regional Committee','1010.101007','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Abudureyimu','Ajiyiming','1962','1988','Deputy Office Chief','People's Bank of China','8510.101','People's Bank of China-Regional Branch','8510.101002','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Abudureyimu','Ajiyiming','1962','1988','Vice-Chairman','Urumqi Federation of Returned Overseas Chinese','6750.237','Urumqi Federation of Returned Overseas Chinese-Executive Committee','6750.237101','Xinjiang Uygur Autonomous Region','9560.035','Xinjiang Uygur Autonomous Region, Urumqi City','9560.035001'"""
# """'Abudureyimu','Ajiyiming','1962','1988','Chief Accountant','People's Bank of China','8510.101','People's Bank of China-Regional Branch','8510.101002','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Abudureyimu','Ajiyiming','1962','1988','Deputy Chief Accountant','People's Bank of China','8510.101','People's Bank of China-Regional Branch','8510.101002','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Abudureyimu','Ajiyiming','1962','1988','Department Head','People's Bank of China','8510.101','People's Bank of China-Regional Branch','8510.101002','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Abudureyimu','Ajiyiming','','','Cashier Assistant','People's Bank of China','8510.101','People's Bank of China-Regional Branch','8510.101002','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Abudureyimu','Ajiyiming','','','Comprehensive Group Leader','People's Bank of China','8510.101','People's Bank of China-Regional Branch','8510.101002','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Abudureyimu','Ajiyiming','','','Office Worker','People's Bank of China','8510.101','People's Bank of China-Regional Branch','8510.101002','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Agya','Losangtudain','1998','2000','Member','CPPCC','1810.101','CPPCC-National Committee','1810.101001','National Committee-Standing Committee','1810.101001002'"""
# """'Agya','Losangtudain','1998','2000','Member','CPPCC','1810.101','CPPCC-National Committee','1810.101001'"""
# """'Agya','Losangtudain','1995','2000','Vice-Chairman','All-China Youth Federation','6750.128'"""
# """'Agya','Losangtudain','1993','1998','Member','CPPCC','1810.101','CPPCC-National Committee','1810.101001'"""
# """'Agya','Losangtudain','1993','1998','Vice-Chairman','CPPCC','1810.101','CPPCC-Provincial Committee','1810.101031','Qinghai Province','9560.025'"""
# """'Agya','Losangtudain','1993','1998','Vice-Chairman','Buddhist Association of China','6770.152'"""
# """'Agya','Losangtudain','1988','1993','Member','CPPCC','1810.101','CPPCC-National Committee','1810.101001'"""
# """'Agya','Losangtudain','','','Deputy Secretary-General','CPPCC','1810.101','CPPCC-Provincial Committee','1810.101031','Qinghai Province','9560.025'"""
# """'Agya','Losangtudain','','','Chairman','Buddhist Association of China','6770.152','Buddhist Association of China-Council','6770.152001'"""
# """'Agya','Losangtudain','','','Director'"""
# """'Agya','Losangtudain','','','Member','Buddhist Association of China','6770.152','Buddhist Association of China-Council','6770.152001'"""
# """'Agya','Losangtudain','','','Vice-Chairman','Provincial Youth Federation','6750.169','Qinghai Province','9560.025'"""
# """'Agya','Losangtudain','','','Member','All-China Youth Federation','6750.128'"""
# """'Agya','Losangtudain','1981','1988','Vice-Chairman','Provincial Buddhist Association','6770.184','Qinghai Province','9560.025'"""
# """'Agya','Losangtudain','1965','','Student','Zhaxi Lhunbo Lamasery','6300.111','Tibet Autonomous Region','9560.034'"""
# """'Agya','Losangtudain','','',' ("Living Buddha'"""
# """'Ai','Baojun','2013','','Director','Shanghai Free-trade Zone Management Committee','3200.305','Shanghai Municipality','9560.029'"""
# """'Ai','Baojun','2008','2013','Vice Mayor','People's Government','2050.101','Shanghai Municipality','9560.029'"""
# """'Ai','Baojun','2003','2008','Deputy','NPC','1610.001'"""
# """'Ai','Baojun','1998','2007','Chief Accountant','Baoshan Iron and Steel Corporation','8010.639'"""
# """'Ai','Baojun','1998','2007','President','Baoshan Iron and Steel Corporation','8010.639'"""
# """'Ai','Baojun','1998','2007','General Manager','Baoshan Iron and Steel Corporation','8010.639'"""
# """'Ai','Baojun','1994','1998','Deputy Chief','Baoshan Iron and Steel Corporation','8010.639','Baoshan Iron and Steel Corporation-Programming Finance Department','8010.639011'"""
# """'Ai','Baojun','1994','1998','Deputy Chief','Baoshan Iron and Steel Corporation','8010.639','Baoshan Iron and Steel Corporation-Finance Department','8010.639009'"""
# """'Ai','Baojun','1994','2000','Deputy General Manager','Baoshan Iron and Steel Corporation','8010.639'"""
# """'Ai','Baojun','1983','1994','Deputy General Accountant','Northeastern University (NEU)','6190.105'"""
# """'Ai','Baojun','1983','1984','Teacher','Northeastern University (NEU)','6190.105','Northeastern University (NEU)-Management Department','6190.105009'"""
# """'Ai','Baojun','1983','','Graduate','Northeastern University (NEU)','6190.105'"""
# """'Ai','Guoxiang','2002','','Academician','Third World Academy of Sciences','6490.801'"""
# """'Ai','Guoxiang','1997','2000','Chairman','International Astronomical Union','6900.731','International Astronomical Union-Executive Committee','6900.731001'"""
# """'Ai','Guoxiang','1993','','Academician','Chinese Academy of Sciences','6410.107'"""
# """'Ai','Guoxiang','1959','1963','Student','Beijing University','6020.101','Beijing University-Physics Department','6020.101008','Beijing Municipality','9560.002'"""
# """'Ai','Husheng','2012','2017','Alternate Member','CPC','1010.101','CPC-Central Committee','1010.101001'"""
# """'Ai','Husheng','2007','2012','Alternate Member','CPC','1010.101','CPC-Central Committee','1010.101001'"""
# """'Ai','Husheng','2007','','Lieutenant General','PLA','5110.101'"""
# """'Ai','Husheng','2007','','Chief-of-Staff','PLA','5110.101','PLA-Regions','5110.101009','Regions-Chengdu Military Region','5110.101009021','Sichuan Province','9560.031','Sichuan Province, Chengdu City','9560.031001'"""
# """'Ai','Husheng','2003','2008','Deputy','NPC','1610.001'"""
# """'Ai','Husheng','2002','2007','Commander','PLA','5110.101','PLA-Services and Arms','5110.101022','Services and Arms-39th Group Army','5110.101022036'"""
# """'Ai','Husheng','2002','2007','Major General','PLA','5110.101'"""
# """'Ai','Pishan','2003','2006','Chairman','CPPCC','1810.101','CPPCC-Provincial Committee','1810.101031','Shaanxi Province','9560.027'"""
# """'Ai','Pishan','2002','2007','Delegate','CPC','1010.101','CPC-National Congress','1010.101003'"""
# """'Ai','Pishan','2002','2003','Vice-Chairman','CPPCC','1810.101','CPPCC-Provincial Committee','1810.101031','Shaanxi Province','9560.027'"""
# """'Ai','Pishan','1998','2003','Deputy','NPC','1610.001'"""
# """'Ai','Pishan','1998','2003','Delegate','Provincial People's Congress','1610.401','Shaanxi Province','9560.027'"""
# """'Ai','Pishan','1997','2002','Deputy Secretary','CPC','1010.101','CPC-Provincial Committee','1010.101005','Shaanxi Province','9560.027'"""
# """'Ai','Pishan','1997','2002','Director','Provincial Law-and-Order Comprehensive Administration Committee','2210.185','Shaanxi Province','9560.027'"""
# """'Ai','Pishan','1997','2002','Director','Provincial Health Care Committee','2210.186','Shaanxi Province','9560.027'"""
# """'Ai','Pishan','1993','1997','Member','CPC','1010.101','CPC-Provincial Committee','1010.101005','Provincial Committee-Standing Committee','1010.101005001','Shaanxi Province','9560.027'"""
# """'Ai','Pishan','1985','1993','Secretary','Public Security Department','2410.116','Public Security Department-General Office','2410.116001','CPC','1010.101','CPC-Leading Party Group','1010.101031','Shaanxi Province','9560.027'"""
# """'Ai','Pishan','1985','1997','Director','Public Security Department','2410.116','Public Security Department-General Office','2410.116001','Shaanxi Province','9560.027'"""
# """'Ai','Pishan','1985','1993','Deputy Secretary','Public Security Department','2410.116','Public Security Department-General Office','2410.116001','CPC','1010.101','CPC-Leading Party Group','1010.101031','Shaanxi Province','9560.027'"""
# """'Ai','Pishan','1985','1993','Deputy Director','Public Security Department','2410.116','Public Security Department-General Office','2410.116001','Shaanxi Province','9560.027'"""
# """'Ai','Pishan','','','Cadre','Cultural Revolution','1020.101','Cultural Revolution-Revolutionary Committee','1020.101033','Revolutionary Committee-Political and Workers Group','1020.101033022','Shaanxi Province','9560.027','Shaanxi Province, Yan'an City','9560.027006'"""
# """'Ai','Pishan','','','Cadre','Public Security Department','2410.116','Public Security Department-Political and Legislative Group','2410.116011','Shaanxi Province','9560.027','Shaanxi Province, Yan'an City','9560.027006'"""
# """'Ai','Pishan','','','Deputy Section Chief','Public Security Department','2410.116','Shaanxi Province','9560.027','Shaanxi Province, Yan'an City','9560.027006'"""
# """'Ai','Pishan','','','Deputy Director','Public Security Department','2410.116','Public Security Department-Political and Legislative Group','2410.116011','Shaanxi Province','9560.027','Shaanxi Province, Yan'an City','9560.027006'"""
# """'Ai','Pishan','','','Member','CPC','1010.101','CPC-County Committee','1010.101019','Shaanxi Province','9560.027','Shaanxi Province, Yan'an City','9560.027006'"""
# """'Ai','Pishan','','','Secretary','CPC','1010.101','CPC-Provincial Committee','1010.101005','Provincial Committee-Political and Legislative Affairs Committee','1010.101005011','Shaanxi Province','9560.027'"""
# """'Ai','Pishan','','','Alternate Member','CPC','1010.101','CPC-Provincial Committee','1010.101005','Shaanxi Province','9560.027'"""
# """'Ai','Pishan','','','Deputy Secretary','CPC','1010.101','CPC-County Committee','1010.101019','Shaanxi Province','9560.027','Shaanxi Province, Yan'an City','9560.027006'"""
# """'Ai','Pishan','1968','','Graduate','Northwest Institute of Politics and  Law','6480.213'"""
# """'Ai','Pishan','1964','','Joined','CPC','1010.101'"""
# """'Ai','Zhisheng','1992','1997','Member','CPC','1010.101','CPC-Central Committee','1010.101001'"""
# """'Ai','Zhisheng','1987','1992','Member','CPC','1010.101','CPC-Central Committee','1010.101001'"""
# """'Ai','Zhisheng','1985','1994','Director','State Administration of Radio, Film and Television','3200.301'"""
# """'Ai','Zhisheng','1983','1985','Secretary-General','State Council','3000.'"""
# """'Ai','Zhisheng','1982','1987','Alternate Member','CPC','1010.101','CPC-Central Committee','1010.101001'"""
# """'Ai','Zhisheng','1979','1983','Deputy Secretary','Tsinghua University','6020.102','CPC','1010.101','CPC-Party Committee','1010.101025','Beijing Municipality','9560.002'"""
# """'Ai','Zhisheng','1979','1983','Vice-President','Tsinghua University','6020.102','Beijing Municipality','9560.002'"""
# """'Ai','Zhisheng','1973','1977','Worker','Cultural Revolution','1020.101','Cultural Revolution-Sent to do manual labor','1020.101104'"""
# """'Ai','Zhisheng','1966','1971','Worker','Cultural Revolution','1020.101','Cultural Revolution-Sent to do manual labor','1020.101104'"""
# """'Ai','Zhisheng','1960','1966','Deputy Secretary','Tsinghua University','6020.102','CPC','1010.101','CPC-Party Committee','1010.101025','Beijing Municipality','9560.002'"""
# """'Ai','Zhisheng','1950','1960','Deputy Secretary','Tsinghua University','6020.102','CPC','1010.101','CPC-Party Branch','1010.101041','Beijing Municipality','9560.002'"""
# """'Alice','Cheung','2003','','Person-in-Charge','Chinese General Chamber of Commerce','6870.001','Chinese General Chamber of Commerce-Training Programs for Senior Chinese Officials','6870.001091','Hong Kong SAR','9560.014'"""
# """'Alice','Cheung','1998','2003','Member','CPPCC','1810.101','CPPCC-National Committee','1810.101001','National Committee-Standing Committee','1810.101001002'"""
# """'Alice','Cheung','1996','2002','Member','1st Hong Kong SAR Government','3200.808','1st Hong Kong SAR Government-Selection Committee','3200.808001'"""
# """'Alice','Cheung','1995','1997','Member','Hong Kong SAR Preparatory Committee','3200.804'"""
# """'Alice','Cheung','1993','1998','Member','CPPCC','1810.101','CPPCC-National Committee','1810.101001','National Committee-Standing Committee','1810.101001002'"""
# """'Alice','Cheung','1992','','Advisor'"""
# """'Alice','Cheung','1992','1997','Member','All-China Federation of Industry and Commerce','6750.126','All-China Federation of Industry and Commerce-Standing Committee','6750.126002'"""
# """'Alice','Cheung','1992','1997','Member','All-China Federation of Industry and Commerce','6750.126','All-China Federation of Industry and Commerce-Executive Committee','6750.126001'"""
# """'Alice','Cheung','1988','1993','Member','CPPCC','1810.101','CPPCC-National Committee','1810.101001'"""
# """'Alice','Cheung','','','General Manager','Yung Shing Enterprise Co.','8010.389','Hong Kong SAR','9560.014'"""
# """'Alice','Cheung','','','Vice-Chairman','Chinese General Chamber of Commerce','6870.001'"""
# """'Alice','Cheung','','','Vice-President','Jinli Supermarket Co., Ltd','8010.388','Hong Kong SAR','9560.014'"""
# """'Alice','Cheung','','','Chairman','Hong Kong Management Association','6770.185','Hong Kong Management Association-Business Enterprise Management Center','6770.185001','Hong Kong SAR','9560.014'"""
# """'Alice','Cheung','','','Managing Director','Taching Petroleum Co., Ltd','8010.387','Hong Kong SAR','9560.014'"""
# """'Alice','Cheung','1961','','Graduate'"""
# """'Aman','Haji','2003','2004','Vice-Chairman','Autonomous Region People's Government','2050.106','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Aman','Haji','1999','2003','Deputy Secretary','Autonomous Region People's Government','2050.106','Autonomous Region People's Government-High-Grade Highway Administration','2050.106022','CPC','1010.101','CPC-Leading Party Group','1010.101031','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Aman','Haji','1995','1996','Director','Autonomous Region People's Government','2050.106','Autonomous Region People's Government-High-Grade Highway Administration','2050.106022','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Aman','Haji','1992','1995','Director','Autonomous Region People's Government','2050.106','Autonomous Region People's Government-Communications Department','2050.106011','Communications Department-Planning Division','2050.106011008','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Aman','Haji','1984','1992','Deputy Director','Autonomous Region People's Government','2050.106','Autonomous Region People's Government-Communications Department','2050.106011','Communications Department-Planning Division','2050.106011008','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Aman','Haji','1983','','Joined','CPC','1010.101'"""
# """'Aman','Haji','1976','1979','Cadre','Autonomous Region People's Government','2050.106','Autonomous Region People's Government-Communications Department','2050.106011','Communications Department-Publicity Section','2050.106011009','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Aman','Haji','1976','','Graduate','Xi'an Jiaotong University','6230.101','Shaanxi Province','9560.027','Shaanxi Province, Xi'an City','9560.027001'"""
# """'Aman','Haji','1962','1971','Worker','Wulasitai Farm','8010.952','Xinjiang Uygur Autonomous Region','9560.035','Xinjiang Uygur Autonomous Region, Bayinguoleng Mongol Prefecture','9560.035026'"""
# """'Amudun','Niyaz','','','Member','CPC','1010.101','CPC-Central Committee','1010.101001','Central Committee-Central Commission for Discipline Inspection','1010.101001039'"""
# """'Amudun','Niyaz','1997','2002','Delegate','CPC','1010.101','CPC-National Congress','1010.101003'"""
# """'Amudun','Niyaz','1993','1998','Deputy','NPC','1610.001'"""
# """'Amudun','Niyaz','1987','1992','Delegate','CPC','1010.101','CPC-National Congress','1010.101003'"""
# """'Amudun','Niyaz','1985','','Secretary','CPC','1010.101','CPC-Autonomous Regional Committee','1010.101007','Autonomous Regional Committee-Politics and Law Committee','1010.101007013','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Amudun','Niyaz','1985','','Deputy Secretary','CPC','1010.101','CPC-Autonomous Regional Committee','1010.101007','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Amudun','Niyaz','1983','','Chairman','Autonomous Regional People's Congress','1610.901','Autonomous Regional People's Congress-Standing Committee','1610.901001','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Amudun','Niyaz','1979','1983','Vice-Chairman','Autonomous Region People's Government','2050.106','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Amudun','Niyaz','1978','1983','Vice-Chairman','Ethnic Affairs Committee of the NPC','1610.201'"""
# """'Amudun','Niyaz','1975','1978','Deputy','NPC','1610.001'"""
# """'Amudun','Niyaz','1973','1978','Secretary','CPC','1010.101','CPC-Autonomous City Committee','1010.101016','Xinjiang Uygur Autonomous Region','9560.035','Xinjiang Uygur Autonomous Region, Urumqi City','9560.035001'"""
# """'Amudun','Niyaz','1973','1978','Deputy Secretary','CPC','1010.101','CPC-Autonomous City Committee','1010.101016','Xinjiang Uygur Autonomous Region','9560.035','Xinjiang Uygur Autonomous Region, Urumqi City','9560.035001'"""
# """'Amudun','Niyaz','1966','1967','Mayor','People's Government','2050.101','Xinjiang Uygur Autonomous Region','9560.035','Xinjiang Uygur Autonomous Region, Urumqi City','9560.035001'"""
# """'Amudun','Niyaz','1962','1966','Deputy Director','Commerce Department','2410.114','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Amudun','Niyaz','1962','1966','Deputy Director','Supply and Marketing Cooperatives','2410.402','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Amudun','Niyaz','1960','1962','Member','CPC','1010.101','CPC-Autonomous County Committee','1010.101021','Autonomous County Committee-Secretariat','1010.101021002','Xinjiang Uygur Autonomous Region','9560.035','Xinjiang Uygur Autonomous Region, Luntai','9560.035009'"""
# """'Amudun','Niyaz','1955','1960','Secretary','CYLC','6777.101','CYLC-Autonomous Prefecture-Level','6777.101626','Xinjiang Uygur Autonomous Region','9560.035','Xinjiang Uygur Autonomous Region, Korla','9560.035014'"""
# """'Amudun','Niyaz','1953','','Joined','CPC','1010.101'"""
# """'An','Jian','2010','2013','Deputy Director','Legislative Affairs Office of the State Council','3400.301'"""
# """'An','Jian','2010','2013','Member','Legislative Affairs Office of the State Council','3400.301','CPC','1010.101','CPC-Leading Party Group','1010.101031'"""
# """'An','Jian','2010','','Vice-Chairman','China Law Society','6770.214'"""
# """'An','Jian','2008','2010','Vice-Chairman','Legislative Affairs Committee of the NPC','1610.216'"""
# """'An','Jian','2008','2010','Director','Legislative Affairs Committee of the NPC','1610.216','Legislative Affairs Committee of the NPC-Economic Law Office','1610.216003'"""
# """'An','Limin','2012','2017','Member','CPC','1010.101','CPC-Central Committee','1010.101001','Central Committee-Central Commission for Discipline Inspection','1010.101001039'"""
# """'An','Min','2003','2005','Member','Ministry of Commerce','3100.276','CPC','1010.101','CPC-Leading Party Group','1010.101031'"""
# """'An','Min','2003','2005','Vice-Minister','Ministry of Commerce','3100.276'"""
# """'An','Min','2001','2003','Vice-Minister','Ministry of Foreign Trade and Economic Cooperation','3100.721'"""
# """'An','Min','1996','2001','Member','Ministry of Foreign Trade and Economic Cooperation','3100.721','CPC','1010.101','CPC-Leading Party Group','1010.101031'"""
# """'An','Min','1996','2001','Assistant Minister','Ministry of Foreign Trade and Economic Cooperation','3100.721'"""
# """'An','Min','1993','1996','Director','Ministry of Foreign Trade and Economic Cooperation','3100.721','Ministry of Foreign Trade and Economic Cooperation-Taiwan, Hong Kong and Macao Affairs Department','3100.721022'"""
# """'An','Min','1992','1993','Director','Ministry of Foreign Economic Relations and Trade','3990.141','Ministry of Foreign Economic Relations and Trade-Taiwan, Hong Kong and Macao Affairs Department','3990.141025'"""
# """'An','Min','1990','1992','Director','Ministry of Foreign Economic Relations and Trade','3990.141','Ministry of Foreign Economic Relations and Trade-Economic and Trade Relations with Taiwan Department','3990.141024'"""
# """'An','Min','1988','1990','Deputy Director','Ministry of Foreign Economic Relations and Trade','3990.141','Ministry of Foreign Economic Relations and Trade-Economic and Trade Relations with Taiwan Department','3990.141024'"""
# """'An','Min','1986','1988','Deputy Director','Ministry of Foreign Economic Relations and Trade','3990.141','Ministry of Foreign Economic Relations and Trade-Office of Trade with Taiwan','3990.141023'"""
# """'An','Min','1982','1986','Division Chief','Ministry of Foreign Economic Relations and Trade','3990.141','Ministry of Foreign Economic Relations and Trade-Import and Export Department','3990.141007'"""
# """'An','Min','1982','1986','Deputy Division Chief','Ministry of Foreign Economic Relations and Trade','3990.141','Ministry of Foreign Economic Relations and Trade-Import and Export Department','3990.141007'"""
# """'An','Min','1982','1986','Staff Member','Ministry of Foreign Economic Relations and Trade','3990.141','Ministry of Foreign Economic Relations and Trade-Import and Export Department','3990.141007'"""
# """'An','Min','1979','1982','Staff Member','Ministry of Foreign Trade and Economic Cooperation','3100.721','Ministry of Foreign Trade and Economic Cooperation-Fourth Bureau','3100.721004'"""
# """'An','Min','1979','','Joined','CPC','1010.101'"""
# """'An','Min','1975','1979','Controller','Huainan Chemical Fertilizer Plant','8010.751','Huainan Chemical Fertilizer Plant-Production Section','8010.751009','Anhui Province','9560.001','Anhui Province, Huainan City','9560.001005'"""
# """'An','Min','1975','1979','Technician','Huainan Chemical Fertilizer Plant','8010.751','Anhui Province','9560.001','Anhui Province, Huainan City','9560.001005'"""
# """'An','Min','1970','1975','Teacher','Hebei Province','9560.011','Hebei Province, Chicheng County','9560.011085'"""
# """'An','Min','1970','','Graduate','University of International Relations','6020.147','University of International Relations-English Department','6020.147009','Beijing Municipality','9560.002'"""
# """'An','Pingsheng','1982','1987','Member','CPC','1010.101','CPC-Central Committee','1010.101001'"""
# """'An','Pingsheng','1977','1982','Member','CPC','1010.101','CPC-Central Committee','1010.101001'"""
# """'An','Pingsheng','1973','1977','Member','CPC','1010.101','CPC-Central Committee','1010.101001'"""
# """'An','Qiyuan','1998','2003','Member','CPPCC','1810.101','CPPCC-National Committee','1810.101001'"""
# """'An','Qiyuan','1998','','Chairman','CPPCC','1810.101','CPPCC-Provincial Committee','1810.101031','Shaanxi Province','9560.027'"""
# """'An','Qiyuan','1997','2002','Delegate','CPC','1010.101','CPC-National Congress','1010.101003'"""
# """'An','Qiyuan','1994','1997','Secretary','CPC','1010.101','CPC-Provincial Committee','1010.101005','Shaanxi Province','9560.027'"""
# """'An','Qiyuan','1993','1997','Delegate','CPC','1010.101','CPC-National Congress','1010.101003'"""
# """'An','Qiyuan','1992','1995','Member','CPC','1010.101','CPC-Central Committee','1010.101001','Central Committee-Central Commission for Discipline Inspection','1010.101001039','Central Commission for Discipline Inspection-Standing Committee','1010.101001039001'"""
# """'An','Qiyuan','','','Secretary','CPC','1010.101','CPC-Provincial Committee','1010.101005','Provincial Committee-Policy and Law Committee','1010.101005086','Shaanxi Province','9560.027'"""
# """'An','Qiyuan','','','Deputy Secretary','CPC','1010.101','CPC-Provincial Committee','1010.101005','Provincial Committee-Policy and Law Committee','1010.101005086','Shaanxi Province','9560.027'"""
# """'An','Qiyuan','','','Secretary','CPC','1010.101','CPC-Municipal Committee','1010.101009','Shaanxi Province','9560.027','Shaanxi Province, Xi'an City','9560.027001'"""
# """'An','Qiyuan','1988','','Member','CPC','1010.101','CPC-Provincial Committee','1010.101005','Provincial Committee-Standing Committee','1010.101005001','Shaanxi Province','9560.027'"""
# """'An','Qiyuan','','','Director','China Seismological Bureau','3600.601'"""
# """'An','Qiyuan','','','Deputy Director','China Seismological Bureau','3600.601'"""
# """'An','Qiyuan','','','Director','Ministry of Petroleum Industry','3100.655','Ministry of Petroleum Industry-Petroleum Geophysical Prospecting Bureau','3100.655011'"""
# """'An','Qiyuan','','','Chief','Daqing Oil Mine','8010.833','Daqing Oil Mine-1st Oil Extracting Headquarters','8010.833001','1st Oil Extracting Headquarters-Underground Operation Section','8010.833001009','Heilongjiang Province','9560.012','Heilongjiang Province, Daqing City','9560.012002'"""
# """'An','Qiyuan','','','Director','Daqing Oil Mine','8010.833','Heilongjiang Province','9560.012','Heilongjiang Province, Daqing City','9560.012002'"""
# """'An','Qiyuan','','','Leader','Petroleum Exploration Bureau','2190.109','Heilongjiang Province','9560.012','Heilongjiang Province, Songliao','9560.012009'"""
# """'An','Qiyuan','1956','','Graduate','Northwest University','6230.102','Northwest University-Geology Department','6230.102007','Shaanxi Province','9560.027'"""
# """'An','Qiyuan','1953','','Joined','CPC','1010.101'"""
# """'An','Zhendong','2003','2008','Vice-Chairman','Provincial People's Congress','1610.401','Provincial People's Congress-Standing Committee','1610.401001','Heilongjiang Province','9560.012'"""
# """'An','Zhendong','1998','2003','Member','CPPCC','1810.101','CPPCC-National Committee','1810.101001','National Committee-Standing Committee','1810.101001002'"""
# """'An','Zhendong','1997','','Vice-Chairman','Jiusan Society','1710.101','Jiusan Society-Central Committee','1710.101001'"""
# """'An','Zhendong','1993','1998','Member','NPC','1610.001'"""
# """'An','Zhendong','1988','1993','Member','NPC','1610.001'"""
# """'An','Zhendong','1983','1988','Member','NPC','1610.001'"""
# """'An','Zhendong','1983','','Vice-Governor','People's Government','2050.101','Heilongjiang Province','9560.012'"""
# """'An','Zhendong','1981','','Joined','Jiusan Society','1710.101'"""
# """'An','Zhendong','','','Chief Engineer','No. 2 Light Industry Bureau','2190.221','Heilongjiang Province','9560.012','Heilongjiang Province, Harbin City','9560.012001'"""
# """'An','Zhendong','','','Deputy Director','Rectification Equipment Factory','8010.386','Heilongjiang Province','9560.012','Heilongjiang Province, Harbin City','9560.012001'"""
# """'An','Zhendong','','','Engineer','Railway Administration','2410.129','Railway Administration-Electric Power Division','2410.129009','Heilongjiang Province','9560.012','Heilongjiang Province, Qiqihar City','9560.012004'"""
# """'An','Zhendong','1951','','Graduate','Hebei Engineering College','6100.162','Hebei Engineering College-Electrical Communications Department','6100.162009','Hebei Province','9560.011'"""
# """'An','Zhisheng','2008','','President','INQUA Commission on Loess','6900.136'"""
# """'An','Zhisheng','1999','2002','Director','Chinese Academy of Sciences','6410.107'"""
# """'An','Zhisheng','1995','2000','Director','State Key Laboratory of Loess and Quaternary Geology','6900.135'"""
# """'An','Zhisheng','1991','','Member','Chinese Academy of Sciences','6410.107'"""
# """'An','Zhisheng','1966','','Graduate','Chinese Academy of Sciences','6410.107','Chinese Academy of Sciences-Geological Research Institute','6410.107057'"""
# """'An','Zhisheng','1962','','Graduate','Nanjing University','6250.179','Jiangsu Province','9560.018','Jiangsu Province, Nanjing City','9560.018001'"""
# """'An','Zhiwen','1982','1987','Alternate Member','CPC','1010.101','CPC-Central Committee','1010.101001'"""
# """'An','Zijie','1993','1998','Vice-Chairman','CPPCC','1810.101','CPPCC-National Committee','1810.101001'"""
# """'An','Ziwen','1956','1969','Member','CPC','1010.101','CPC-Central Committee','1010.101001'"""
# """'Anwar','Amut','2000','','President','Xinjiang University','6310.101','Xinjiang Uygur Autonomous Region','9560.035','Xinjiang Uygur Autonomous Region, Urumqi City','9560.035001'"""
# """'Anwar','Amut','1999','2000','Deputy Director','Seismic Bureau','2190.313','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Anwar','Amut','1999','2000','President','Xinjiang Engineering Institute','6310.121','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Anwar','Amut','1977','','Graduate','Beijing University','6020.101','Beijing University-Geophysics Department','6020.101029','Beijing Municipality','9560.002'"""
# """'Arken','Imirbaki','2013','','Vice-Chairman','Standing Committee of the NPC','1610.101'"""
# """'Arken','Imirbaki','2001','','Member','CPC','1010.101','CPC-Autonomous Regional Committee','1010.101007','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Arken','Imirbaki','2001','','Vice-Chairman','Autonomous Region People's Government','2050.106','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Arken','Imirbaki','1999','2001','Secretary-General','Autonomous Region People's Government','2050.106','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Arken','Imirbaki','1997','1999','Deputy Secretary','Electronics Industry Department','2410.275','CPC','1010.101','CPC-Party Committee','1010.101025','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Arken','Imirbaki','1997','1999','Director General','Electronics Industry Department','2410.275','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Arken','Imirbaki','1994','1997','Deputy Director-General','Economic and Trade Committee','2210.451','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Arken','Imirbaki','1992','1994','Assistant to Mayor','People's Government','2050.101','Xinjiang Uygur Autonomous Region','9560.035','Xinjiang Uygur Autonomous Region, Urumqi City','9560.035001'"""
# """'Arken','Imirbaki','1980','','Joined','CPC','1010.101'"""
# """'Aronhan'aji','','2003','2005','Vice-President','Autonomous Region People's Government','2050.106','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Aronhan'aji','','','','President','Xinjiang Uygur Islamic Association','6770.347'"""
# """'Aronhan'aji','','','','Vice-President','CPPCC','1810.101','CPPCC-Autonomous Regional Committee','1810.101033','Xinjiang Uygur Autonomous Region','9560.035','Xinjiang Uygur Autonomous Region, Keshen','9560.035012'"""
# """'Aronhan'aji','','','','Vice-Chairman','China Islamic Association','6770.254'"""
# """'Ashanbaike','Turdi','2001','','Deputy Director','Autonomous Regional People's Congress','1610.901','Autonomous Regional People's Congress-Standing Committee','1610.901001','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Ashanbaike','Turdi','1998','2001','Director','Autonomous District People's Congress','1610.904','Autonomous District People's Congress-Standing Committee','1610.904001','Xinjiang Uygur Autonomous Region','9560.035','Xinjiang Uygur Autonomous Region, Kezilesu District','9560.035037'"""
# """'Ashanbaike','Turdi','1993','1998','Deputy Secretary','CPC','1010.101','CPC-Autonomous District Committee','1010.101018','Xinjiang Uygur Autonomous Region','9560.035','Xinjiang Uygur Autonomous Region, Kezilesu District','9560.035037'"""
# """'Ashanbaike','Turdi','1992','1993','Subcomissioner','Xinjiang Uygur Autonomous Region','9560.035','Xinjiang Uygur Autonomous Region, Kezilesu District','9560.035037'"""
# """'Ashanbaike','Turdi','1990','1992','Secretary','CPC','1010.101','CPC-Autonomous District Committee','1010.101018','Autonomous District Committee-Commission for Discipline Inspection','1010.101018009','Xinjiang Uygur Autonomous Region','9560.035','Xinjiang Uygur Autonomous Region, Kezilesu District','9560.035037'"""
# """'Ashanbaike','Turdi','1990','1992','Member','CPC','1010.101','CPC-Autonomous District Committee','1010.101018','Autonomous District Committee-Standing Committee','1010.101018001','Xinjiang Uygur Autonomous Region','9560.035','Xinjiang Uygur Autonomous Region, Kezilesu District','9560.035037'"""
# """'Ashanbaike','Turdi','1987','1990','Magistrate','County (District) People's Court','4020.103','Xinjiang Uygur Autonomous Region','9560.035','Xinjiang Uygur Autonomous Region, Wuqia County','9560.035038'"""
# """'Ashanbaike','Turdi','1974','','Joined','CPC','1010.101'"""
# """'Ashanbaike','Turdi','1971','1987','Director','Education Bureau','2190.124','Xinjiang Uygur Autonomous Region','9560.035','Xinjiang Uygur Autonomous Region, Wuqia County','9560.035038'"""
# """'Ashanbaike','Turdi','1964','1971','Culture and Education Secretary','People's Government','2050.101','Xinjiang Uygur Autonomous Region','9560.035','Xinjiang Uygur Autonomous Region, Kezilesu District','9560.035037'"""
# """'Ashanbaike','Turdi','1962','1964','Student','Kezilesu Normal School','6310.129','Xinjiang Uygur Autonomous Region','9560.035','Xinjiang Uygur Autonomous Region, Kezilesu District','9560.035037'"""
# """'Ashat','Kerimbay','2007','2012','Member','CPC','1010.101','CPC-Central Committee','1010.101001'"""
# """'Ashat','Kerimbay','2003','2008','Member','CPPCC','1810.101','CPPCC-National Committee','1810.101001'"""
# """'Ashat','Kerimbay','2003','','Chairman','CPPCC','1810.101','CPPCC-Autonomous Regional Committee','1810.101033','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Ashat','Kerimbay','2002','2007','Alternate Member','CPC','1010.101','CPC-Central Committee','1010.101001'"""
# """'Ashat','Kerimbay','2001','2006','Member','CPC','1010.101','CPC-Autonomous Regional Committee','1010.101007','Autonomous Regional Committee-Standing Committee','1010.101007011','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Ashat','Kerimbay','1997','2002','Alternate Member','CPC','1010.101','CPC-Central Committee','1010.101001'"""
# """'Ashat','Kerimbay','1996','2006','Deputy Secretary','CPC','1010.101','CPC-Autonomous Regional Committee','1010.101007','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Ashat','Kerimbay','1993','1998','Deputy','NPC','1610.001'"""
# """'Ashat','Kerimbay','1993','1996','Vice-Chairman','Autonomous Region People's Government','2050.106','Xinjiang Uygur Autonomous Region','9560.035'"""
# """'Ashat','Kerimbay','1988','1993','Governor','People's Government','2050.101','Xinjiang Uygur Autonomous Region','9560.035','Xinjiang Uygur Autonomous Region, Ili Kazak Prefecture','9560.035013'"""
# """'Ashat','Kerimbay','1988','1993','Magistrate','Intermediate People's Court','4020.102','Xinjiang Uygur Autonomous Region','9560.035','Xinjiang Uygur Autonomous Region, Ili Kazak Prefecture','9560.035013'"""
# """'Ashat','Kerimbay','1988','1993','Deputy','NPC','1610.001'"""
# """'Ashat','Kerimbay','1988','1993','Deputy Secretary','CPC','1010.101','CPC-Autonomous Prefectural Committee','1010.101013','Xinjiang Uygur Autonomous Region','9560.035','Xinjiang Uygur Autonomous Region, Ili Kazak Prefecture','9560.035013'"""
# """'Ashat','Kerimbay','1987','1988','Secretary','Ili Teachers' College','6310.109','CPC','1010.101','CPC-Party Committee','1010.101025','Xinjiang Uygur Autonomous Region','9560.035','Xinjiang Uygur Autonomous Region, Yili','9560.035002'"""
# """'Ashat','Kerimbay','1984','1987','Deputy Commissioner','Prefectural Administrative Office','2410.111','Xinjiang Uygur Autonomous Region','9560.035','Xinjiang Uygur Autonomous Region, Yili','9560.035002'"""
# """'Ashat','Kerimbay','1976','1983','Deputy Head','CPC','1010.101','CPC-Autonomous Prefectural Committee','1010.101013','Autonomous Prefectural Committee-Organization Department','1010.101013006','Xinjiang Uygur Autonomous Region','9560.035','Xinjiang Uygur Autonomous Region, Yili','9560.035002'"""
# """'Ashat','Kerimbay','1975','','Joined','CPC','1010.101'"""
# """'Ashat','Kerimbay','1972','1976','Magistrate','County (District) People's Court','4020.103','Xinjiang Uygur Autonomous Region','9560.035','Xinjiang Uygur Autonomous Region, Yining County','9560.035029'"""
# """'Ashat','Kerimbay','1970','1972','Soldier','PLA','5110.101'"""
# """'Ashat','Kerimbay','1970','','Graduate','Xinjiang University','6310.101','Xinjiang University-Chinese Language and Literature Department','6310.101009','Xinjiang Uygur Autonomous Region','9560.035'"""
